# %% [markdown]
# # Notebook 1 — Persiapan Data
#
# Memuat dan memvalidasi dataset prompt dari jurnal Oprea & Bâra (2026).

# %%
import pandas as pd
import sys
sys.path.append('../scripts')
from utils import load_prompts
print('Library berhasil dimuat')

# %% [markdown]
# ## 1. Muat dataset prompt

# %%
prompts_text = load_prompts('../dataset/prompts_text.txt')
prompts_code = load_prompts('../dataset/prompts_code.txt')
print(f'Prompt teks  : {len(prompts_text)}')
print(f'Prompt kode  : {len(prompts_code)}')
print(f'Total        : {len(prompts_text)+len(prompts_code)}')

# %% [markdown]
# ## 2. Tampilkan ringkasan dataset

# %%
df = pd.read_csv('../dataset/dataset_summary.csv')
print(df.groupby(['kategori','tipe']).size().reset_index(name='jumlah'))
df.head(10)

# %% [markdown]
# ## 3. Validasi prompt utama jurnal (2 prompt)

# %%
utama = df[df['tipe']=='Utama']
for _, row in utama.iterrows():
    print(f"ID {row['id']}: {row['prompt']}")

# %% [markdown]
# ## 4. Distribusi kategori

# %%
print('Dataset siap. Ringkasan:')
print(df['kategori'].value_counts())
